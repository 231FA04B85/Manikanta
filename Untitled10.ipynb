# %% [markdown]
# <a href="https://colab.research.google.com/github/231FA04B85/Manikanta/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install googletrans==4.0.0-rc1

# %%
from googletrans import Translator
t = Translator()
text = input("Enter a text:")
translated = t.translate(text,src='en',dest='hi')
print("Translated.text:",translated.text)
# Out:
# Enter a text:hi baby
# Translated.text: हाय बेबी

# %%
# !pip install pytesseract pillow

# %%
from PIL import Image
import pytesseract
import matplotlib.pyplot as plt
ip =  "/content/jijijkij.jpg"
plt.imshow(Image.open(ip))
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(346.5), np.float64(144.5), np.float64(-0.5))

# %%
img = Image.open(ip)
text = pytesseract.image_to_string(img)
print("extracted text:",text)
# Out:
# extracted text:

# %%
# !pip install gtts
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 9.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.2.0
#     Uninstalling click-8.2.0:
#       Successfully uninstalled click-8.2.0
# ...

# %%
from gtts import gTTS
b=gTTS(text)
b.save("text.mp3")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-20-a8b200fa2da6> in <cell line: 0>()
#       1 from gtts import gTTS
#       2 b=gTTS(text)
# ----> 3 b.save("text.mp3")
#
# /usr/local/lib/python3.11/dist-packages/gtts/tts.py in save(self, savefile)
#     333         """
#     334         with open(str(savefile), "wb") as f:
# --> 335             self.write_to_fp(f)
#     336             f.flush()
#     337             log.debug("Saved to %s", savefile)
#
# /usr/local/lib/python3.11/dist-packages/gtts/tts.py in write_to_fp(self, fp)
#     314
#     315         try:
# --> 316             for idx, decoded in enumerate(self.stream()):
#     317                 fp.write(decoded)
#     318                 log.debug("part-%i written to %s", idx, fp)
#
# /usr/local/lib/python3.11/dist-packages/gtts/tts.py in stream(self)
#     261             pass
#     262
# ...
